# %%
# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Reading the CSV file
obesity_df = pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv')  
print(obesity_df.columns)
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
obesity_df['Age']=obesity_df['Age'].round()
obesity_df['Height']=obesity_df['Height'].round(2)
obesity_df['Weight']=obesity_df['Weight'].round(1)
obesity_df['FCVC']=obesity_df['FCVC'].round()
obesity_df['NCP']=obesity_df['NCP'].round()
obesity_df['CH2O']=obesity_df['CH2O'].round()
obesity_df['FAF']=obesity_df['FAF'].round()
obesity_df['TUE']=obesity_df['TUE'].round()

# %%
obesity_df.tail()
# Out:
#       Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 2106  Female  21.0    1.71   131.4                            yes  yes   3.0
# 2107  Female  22.0    1.75   133.7                            yes  yes   3.0
# 2108  Female  23.0    1.75   133.7                            yes  yes   3.0
# 2109  Female  24.0    1.74   133.3                            yes  yes   3.0
# 2110  Female  24.0    1.74   133.5                            yes  yes   3.0
#
#       NCP       CAEC SMOKE  CH2O SCC  FAF  TUE       CALC  \
# 2106  3.0  Sometimes    no   2.0  no  2.0  1.0  Sometimes
# 2107  3.0  Sometimes    no   2.0  no  1.0  1.0  Sometimes
# 2108  3.0  Sometimes    no   2.0  no  1.0  1.0  Sometimes
# 2109  3.0  Sometimes    no   3.0  no  1.0  1.0  Sometimes
# 2110  3.0  Sometimes    no   3.0  no  1.0  1.0  Sometimes
#
#                      MTRANS        NObeyesdad
# 2106  Public_Transportation  Obesity_Type_III
# 2107  Public_Transportation  Obesity_Type_III
# ...

# %%
sns.boxplot(x='Age', y='NObeyesdad', data=obesity_df, orient='h')
plt.ylabel('Obesity Level')
plt.show()

# %%
sns.boxplot(x='Height', y='NObeyesdad', data=obesity_df, orient='h')
plt.ylabel('Obesity Level')
plt.show()

# %%
sns.boxplot(x='Weight', y='NObeyesdad', data=obesity_df, orient='h')
plt.ylabel('Obesity Level')
plt.show()

# %%
sns.boxplot(x='FCVC', y='NObeyesdad', data=obesity_df, orient='h')
plt.xlabel('How often Vegetables are Consumed')
plt.ylabel('Obesity Level')
plt.show()

# %%
sns.boxplot(x='NCP', y='NObeyesdad', data=obesity_df, orient='h')
plt.xlabel('Number of Main Meals each Day')
plt.ylabel('Obesity Level')
plt.show()

# %%
sns.boxplot(x='CH2O', y='NObeyesdad', data=obesity_df, orient='h')
plt.xlabel('Number of Liters of Water per day')
plt.ylabel('Obesity Level')
plt.show()

# %%
sns.boxplot(x='FAF', y='NObeyesdad', data=obesity_df, orient='h')
plt.xlabel('Days of Physical Activity')
plt.ylabel('Obesity Level')
plt.show()

# %%
sns.boxplot(x='TUE', y='NObeyesdad', data=obesity_df, orient='h')
plt.xlabel('Hours Spent on Technological Devices')
plt.ylabel('Obesity Level')
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['Insufficient_Weight', 'Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II', 'Obesity_Type_I', 'Obesity_Type_II', 'Obesity_Type_III']
values1 = []
values2 = []
for i in categories:
    values1.append((obesity_df[obesity_df['NObeyesdad'] == i]['family_history_with_overweight']=='yes').sum())
    values2.append((obesity_df[obesity_df['NObeyesdad'] == i]['family_history_with_overweight']=='no').sum())

# Define the width of the bars
bar_width = 0.2

# Calculate the position of each group of bars on the x-axis
x = range(len(categories))

# Create the first set of bars
plt.bar(x, values1, width=bar_width, label='Yes')

# Create the second set of bars, shifting the x positions to the right
plt.bar([pos + bar_width for pos in x], values2, width=bar_width, label='No')

# Add labels and title
plt.xlabel('Obesity Levels', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Family History with Overweight')
plt.xticks([pos + bar_width / 2 for pos in x], categories, rotation=45, ha='right')  # Set x-axis labels
plt.legend()

# Show plot
plt.tight_layout()
plt.show()
# Out:
# [126, 155, 209, 272, 344, 296, 324]
# [146, 132, 81, 18, 7, 1, 0]

# %%
# Gender distribution
sns.countplot(x='Gender', hue='NObeyesdad', data=obesity_df)
plt.title('Gender by Obesity Level')
plt.show()

# Family history impact
sns.countplot(x='family_history_with_overweight', hue='NObeyesdad', data=obesity_df)
plt.title('Family History with Overweight by Obesity Level')
plt.show()


# Relationship between Height and Weight for differnt Obesity Levels
sns.scatterplot(x='Height', y='Weight', hue='NObeyesdad', data=obesity_df)
plt.title('Height vs. Weight by Obesity Level')
plt.show()

# Relationship between Age and Weight  for differnt Obesity Levels
sns.scatterplot(x='Age', y='Weight', hue='NObeyesdad', data=obesity_df)
plt.title('Age vs. Weight by Obesity Level')
plt.show()

# Relationship between Age and Height for differnt Obesity Levels 
sns.scatterplot(x='Age', y='Weight', hue='NObeyesdad', data=obesity_df)
plt.title('Age vs. Weight by Obesity Level')
plt.show()


# heatmap to show correlation matrix between continuous features
correlation_matrix = obesity_df[['Age','Height','Weight', 'FCVC','NCP','CH2O','FAF','TUE']].corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix')
plt.show()
